# %% [markdown]
# # Load Dataset

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV file
df = pd.read_csv('data/fraud_dataset_raw.csv')

# %% [markdown]
# # Basic Information

# %%
# Dataset shape
print("Dataset shape:", df.shape)
# Info about data types and missing values
df.info()
# Basic statistics for numerical columns
df.describe()
# Out:
# Dataset shape: (53420, 24)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53420 entries, 0 to 53419
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   amount                  53420 non-null  float64
#  1   browser                 43213 non-null  object
#  2   channel                 53420 non-null  object
#  3   customer_age            53157 non-null  float64
#  4   date                    53420 non-null  object
#  5   fraud                   53420 non-null  float64
#  6   ip                      43213 non-null  object
#  7   isp                     43213 non-null  object
#  8   latitude                43213 non-null  object
#  9   loginTime               43213 non-null  object
#  10  longitude               43213 non-null  object
#  11  lut_first_paid_date     40001 non-null  object
#  12  lut_last_paid_date      40001 non-null  object
#  13  minute_of_day           53420 non-null  float64
#  14  onceoff_vs_beneficiary  53420 non-null  object
#  15  os                      43213 non-null  object
#  16  paymentType             53420 non-null  object
#  17  region                  43213 non-null  object
#  18  rtc_indicator           53420 non-null  int64
#  19  to_acc_volume           53420 non-null  float64
#  20  to_bank                 47274 non-null  object
#  21  txn_timestamp           53420 non-null  object
#  22  uuid                    0 non-null      float64
#  23  transactor_id           53420 non-null  float64
# dtypes: float64(7), int64(1), object(16)
# memory usage: 9.8+ MB
#              amount  customer_age         fraud  minute_of_day  rtc_indicator  \
# count  5.342000e+04  53157.000000  53420.000000   53420.000000   53420.000000
# mean   8.129677e+03     45.984687      0.064021     716.935923       0.040565
# std    6.521779e+04     26.811421      0.244793     415.344481       0.197283
# min    1.800000e-01      0.000000      0.000000       0.000000       0.000000
# 25%    3.108925e+02     31.000000      0.000000     355.000000       0.000000
# 50%    1.100000e+03     48.000000      0.000000     717.000000       0.000000
# 75%    3.825000e+03     68.000000      0.000000    1074.000000       0.000000
# max    8.000000e+06     99.000000      1.000000    1439.000000       1.000000
#
#        to_acc_volume  uuid  transactor_id
# count   5.342000e+04   0.0   5.342000e+04
# mean    8.414774e+04   NaN   1.273563e+07
# std     2.159379e+05   NaN   7.536294e+07
# min     0.000000e+00   NaN   1.736000e+03
# 25%     1.000000e+01   NaN   2.462684e+06
# 50%     1.040000e+02   NaN   5.191519e+06
# 75%     2.621800e+04   NaN   9.951466e+06
# max     1.883463e+06   NaN   1.108927e+09

# %% [markdown]
# # Drop uuid column

# %%
df = df.drop(columns=['uuid'])

# %% [markdown]
# # Fill missing categorical columns with "Unknown"

# %%
cat_cols = ['browser', 'ip', 'isp', 'os', 'region', 'to_bank']
df[cat_cols] = df[cat_cols].fillna('Unknown')

# %% [markdown]
# # Fill missing customer_age with median

# %%
df['customer_age'] = df['customer_age'].fillna(df['customer_age'].median())

# %% [markdown]
# # Fill missing lut_first_paid_date, lut_last_paid_date with a placeholder

# %%
df['lut_first_paid_date'] = df['lut_first_paid_date'].fillna('1970-01-01')
df['lut_last_paid_date'] = df['lut_last_paid_date'].fillna('1970-01-01')

# %% [markdown]
# # Convert object columns to datetime

# %%
date_cols = ['date','loginTime','lut_first_paid_date','lut_last_paid_date','txn_timestamp']
for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# %% [markdown]
# # Convert latitude and longitude to float

# %%
df['latitude'] = pd.to_numeric(df['latitude'], errors='coerce')
df['longitude'] = pd.to_numeric(df['longitude'], errors='coerce')

# %% [markdown]
# # Check Updated table

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53420 entries, 0 to 53419
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   amount                  53420 non-null  float64
#  1   browser                 53420 non-null  object
#  2   channel                 53420 non-null  object
#  3   customer_age            53420 non-null  float64
#  4   date                    53420 non-null  datetime64[ns]
#  5   fraud                   53420 non-null  float64
#  6   ip                      53420 non-null  object
#  7   isp                     53420 non-null  object
#  8   latitude                42311 non-null  float64
#  9   loginTime               43213 non-null  datetime64[ns, UTC]
#  10  longitude               42311 non-null  float64
#  11  lut_first_paid_date     40001 non-null  datetime64[ns, UTC]
#  12  lut_last_paid_date      40001 non-null  datetime64[ns, UTC]
#  13  minute_of_day           53420 non-null  float64
#  14  onceoff_vs_beneficiary  53420 non-null  object
#  15  os                      53420 non-null  object
#  16  paymentType             53420 non-null  object
#  17  region                  53420 non-null  object
#  18  rtc_indicator           53420 non-null  int64
#  19  to_acc_volume           53420 non-null  float64
#  20  to_bank                 53420 non-null  object
#  21  txn_timestamp           53420 non-null  datetime64[ns, UTC]
#  22  transactor_id           53420 non-null  float64
# dtypes: datetime64[ns, UTC](4), datetime64[ns](1), float64(8), int64(1), object(9)
# memory usage: 9.4+ MB

# %%
for col in cat_cols:
    print(col, df[col].unique())
# Out:
# browser ['Chrome_Some(66)' 'Chrome_Some(89)' 'Chrome_Some(75)' 'Chrome_Some(77)'
#  'Chrome_Some(49)' 'Chrome_Some(64)' 'Chrome_Some(86)' 'Edge_Some(86)'
#  'Chrome_Some(90)' 'Chrome_Some(87)' 'IE_Some(11)' 'Chrome_Some(79)'
#  'Edge_Some(12)' 'Unknown' 'Chrome_Some(88)' 'Firefox_Some(48)'
#  'Chrome_Some(94)' 'Chrome_Some(69)' 'Chrome_Some(37)' 'Chrome_Some(68)'
#  'Chrome_Some(57)' 'Mobile_Safari_Some(12)' 'Edge_Some(88)'
#  'Chrome_Some(92)' 'HeadlessChrome_Some(77)' 'Chrome_Some(93)'
#  'Chrome_Some(65)' 'Edge_Some(89)' 'Firefox_Some(66)' 'Firefox_Some(92)'
#  'Chrome_Some(48)' 'Chrome_Some(76)' 'Chrome_Some(83)' 'Chrome_Some(74)'
#  'HeadlessChrome_Some(66)' 'Chrome_Some(73)' 'Firefox_Some(90)'
#  'Firefox_Some(70)' 'Other_None' 'Chrome_Some(78)' 'Chrome_Some(70)'
#  'Safari_Some(13)' 'Safari_Some(12)' 'Firefox_Some(52)'
#  'Mobile_Safari_Some(9)' 'Chrome_Some(67)' 'Firefox_Some(67)'
#  'Firefox_Some(65)' 'Firefox_Some(91)' 'Maxthon_Some(4)' 'Edge_Some(16)'
#  'Firefox_Some(64)' 'Chrome_Some(85)' 'Chrome_Some(80)' 'Safari_Some(11)'
#  'Edge_Some(18)' 'Edge_Some(17)' 'Firefox_Some(74)' 'Chrome_Some(91)'
#  'Chrome_Some(71)' 'Chrome_Some(84)' 'Edge_Some(91)' 'Chrome_Some(72)'
#  'Edge_Some(92)' 'Firefox_Some(59)' 'Firefox_Some(85)' 'Chrome_Some(63)'
#  'Safari_Some(10)' 'Edge_Some(87)' 'Chrome_Some(81)' 'Edge_Some(15)'
#  'Firefox_Some(86)' 'Edge_Some(94)' 'Firefox_Some(38)' 'Edge_Some(90)'
#  'Chrome_Mobile_WebView_Some(68)' 'Firefox_Some(82)' 'Edge_Some(83)'
#  'Samsung_Internet_Some(9)' 'Firefox_Some(78)' 'Firefox_Some(88)'
#  'Safari_Some(9)' 'PhantomJS_Some(2)' 'Firefox_Some(68)'
#  'Firefox_Some(57)' 'Firefox_Some(87)' 'Firefox_Some(81)'
#  'Chrome_Mobile_iOS_Some(69)' 'Firefox_Some(62)' 'Firefox_Some(89)'
#  'Firefox_Some(32)' 'Chrome_Some(56)' 'Chrome_Mobile_iOS_Some(74)'
#  'Opera_Some(55)' 'Edge_Some(85)' 'Safari_Some(14)' 'Opera_Some(72)'
#  'Firefox_Some(77)' 'Chrome_Some(55)' 'Firefox_Some(84)'
#  'Firefox_Some(61)' 'Firefox_Some(63)' 'Chrome_Mobile_WebView_Some(54)'
#  'Firefox_Some(60)' 'Firefox_Some(73)' 'Firefox_Some(58)'
#  'Firefox_Some(69)' 'Firefox_Some(47)' 'Firefox_Some(56)'
#  'Chrome_Mobile_WebView_Some(50)' 'Firefox_Some(76)'
#  'HeadlessChrome_Some(79)' 'Mobile_Safari_Some(10)' 'Chrome_Some(58)'
#  'Edge_Some(93)' 'HeadlessChrome_Some(73)' 'Firefox_Some(80)'
#  'Firefox_Some(79)' 'IE_Some(9)' 'Firefox_Some(83)' 'Firefox_Some(4)'
#  'Firefox_Some(71)' 'Safari_Some(6)' 'Edge_Some(13)'
#  'Samsung_Internet_Some(3)' 'Chrome_Some(54)' 'Safari_Some(8)'
#  'Chrome_Some(62)' 'Edge_Some(84)' 'Firefox_Some(72)' 'Opera_Some(56)'
#  'Firefox_Some(93)' 'Opera_Some(76)' 'Mobile_Safari_Some(11)'
#  'Opera_Some(60)' 'Opera_Some(75)' 'Opera_Some(62)' 'Opera_Some(78)'
#  'Edge_Some(14)' 'Firefox_Some(45)' 'Firefox_Some(46)'
#  'Chrome_Mobile_WebView_Some(28)' 'Firefox_Some(75)' 'IE_Some(10)'
#  'Chrome_Mobile_iOS_Some(85)' 'Opera_Some(74)'
#  'Chrome_Mobile_WebView_Some(70)' 'Vivaldi_Some(2)' 'Safari_Some(5)'
#  'Chrome_Some(60)' 'HeadlessChrome_Some(68)' 'Safari_Some(15)'
#  'Chrome_Mobile_WebView_Some(30)' 'Opera_Some(79)' 'Opera_Some(51)'
#  'Chrome_Some(61)' 'Opera_Some(58)' 'Apple_Mail_Some(605)'
#  'Google_Some(73)' 'Firefox_Some(44)' 'Chrome_Some(95)' 'Google_Some(68)'
#  'Opera_Some(50)' 'Opera_Some(73)' 'Samsung_Internet_Some(13)'
#  'Firefox_Some(19)' 'Firefox_Some(49)' 'Firefox_Some(40)'
#  'Chromium_Some(65)' 'Safari_Some(7)' 'Firefox_Some(53)'
#  'HeadlessChrome_Some(71)' 'Firefox_iOS_Some(14)' 'Mobile_Safari_Some(14)'
#  'Opera_Some(57)' 'Edge_Some(77)' 'Chrome_Mobile_iOS_Some(66)'
#  'Opera_Some(64)' 'Chrome_Mobile_iOS_Some(87)'
#  'Chrome_Mobile_iOS_Some(86)' 'Opera_Some(68)' 'Opera_Some(66)'
#  'Chromium_Some(66)' 'Chrome_Mobile_iOS_Some(76)' 'Opera_Some(63)'
#  'Edge_Some(80)' 'Opera_Some(71)' 'HeadlessChrome_Some(62)'
#  'Opera_Some(67)' 'Chrome_Mobile_iOS_Some(83)' 'Mobile_Safari_Some(13)'
#  'Opera_Some(77)' 'Chrome_Mobile_WebView_Some(91)'
#  'HeadlessChrome_Some(70)' 'Opera_Some(65)' 'Opera_Some(69)'
#  'Edge_Some(79)' 'Chrome_Mobile_WebView_Some(58)' 'Firefox_Some(43)'
#  'Vivaldi_Some(1)' 'Chrome_Some(34)' 'Samsung_Internet_Some(8)'
#  'Chrome_Some(52)' 'Chromium_Some(64)' 'Opera_Some(52)' 'Chrome_Some(59)'
#  'Samsung_Internet_Some(2)' 'Google_Some(67)'
#  'Chrome_Mobile_WebView_Some(69)' 'Firefox_Some(21)'
#  'Chrome_Mobile_WebView_Some(92)' 'Chrome_Mobile_WebView_Some(94)'
#  'HeadlessChrome_Some(67)' 'Edge_Some(81)' 'Opera_Some(53)'
#  'Chrome_Some(31)' 'Chrome_Mobile_iOS_Some(92)' 'Edge_Some(78)'
#  'Chrome_Mobile_iOS_Some(70)' 'Chrome_Mobile_iOS_Some(67)']
# ip ['102.253.144.146' '197.89.21.227' '169.0.104.125' ... '105.9.59.75'
#  '185.125.224.24' '41.147.0.25']
# isp ['TelkomInternet' 'OPTINET' 'AFRIHOSTOTHER' 'Amazoncom' 'MWEB'
#  'airmobilecoza' 'Etisalat' 'Cybersmart' 'MTNBusinessSolutions' 'rain'
#  'InternetSolutions' 'Unknown' 'Vodacom' 'LiquidIntelligentTechnologies'
#  'BITCO' 'SyrexPtyLtd' 'Seacom' 'truviewLLC' 'VoxTelecom' 'iiNetConnect'
#  'iSwitchCommunications' 'AFRIHOSTFIBRE' 'Coolideas'
#  'AccessPointTechnologies' 'HeroTel' 'FAIRCAPE' 'unknown' 'ONEWIRELESS'
#  'TelkomLimited' 'Interworks' 'AccessGlobalCommunicationPtyLtd' 'iSPACE'
#  'Greenflash' 'BunduNetworX' 'VodacomBusiness' 'SARB' 'Level7Internet'
#  'Level7' 'CellC' 'M247Ltd' 'BDCWireless' 'Eskomholdingssocltd' 'wirulink'
#  'Zscaler' 'HollywoodSportsbooks' 'WebAfricaNetworks' 'Cmcnetworks'
#  'Rocketnet' 'TWKCommunications' 'Heficed' 'HomeConnect'
#  'SymantecEndpointProtection' 'DaDTactical' 'ScreamerTelecoms' 'SITA'
#  'AxxessNetworks' 'iConnect' 'Ultimatelinux' 'Firestream' 'Eniig'
#  'ChinaTelecom' 'HostAfrica' 'SafcorFreight' 'Jennyinternet' 'OrangeMali'
#  'Level7InternetPTYLTD' 'ComcastCable' 'COMTEL' 'Iclixcc' 'EchoSP'
#  'PawPawWireless' 'SKYWIRE' 'SouthAfricaUniversityNetwork' 'TRUSC'
#  'RSAWEB' 'AirtelZambia' 'Wananchi' 'InternetUncapped' 'Letabanetworks'
#  'SouthAfricanDigitalVillages' 'FORTHnetSA' 'Vodacomlesotho'
#  'Init7SwitzerlandLtd' 'DataKeepers' 'BT' 'Triponza' 'Breebandcoza'
#  'FibreStream' 'IMPOL' 'TIENET' 'RMSPowertronics' 'JumboTechnologies'
#  'LimpoWiFi' 'MyOwnISP' 'EquationBusinessSolutions' 'Africainx' 'xneelo'
#  'ASERGOScandinaviaApS' 'UNITEL' 'ATT' 'FixedMobileTelco'
#  'MultichoiceSupportServices' 'Iclix' 'AccessGlobal' 'McAfee' 'Logicalis'
#  'ClearAccess' 'Centracom' 'ZA1Grid' 'GBWireless' 'SkyBroadband'
#  'ForcepointCloud' 'Capeconnect' 'VANILLA' 'RayvProductDevelopmentPtyLtd'
#  'VlocityCommunications' 'WiberSolutions' 'MetrofibreNetworx'
#  'ActiveFibre' 'COMAIR' 'AvantiBroadbandLtd' 'UCT' 'InternetSA' 'Afrihost'
#  'EconetTelecomLesotho' 'WIOCC' 'OBO' 'EMID' 'Optus' 'Uniwisp'
#  'TesucoTelecommunications' 'Eyjhb' 'CoolIdeas' 'EirBroadband'
#  'TheComputerHut' 'ConvergedTelecoms' 'RTSNetPtyLtd' 'VirginMedia'
#  'WorldStreamBV' 'TurkcellSuperonline' 'DiscoverySouthAfrica'
#  'VoiceandDataTelecoms' 'VodafoneNewZealand' 'QDATA' 'SouthCoast'
#  'UKDedicatedServersLimited' 'GoConnect' 'TechnolutionsPtyLtd' 'ikeja'
#  'ECHOSP' 'ICTGLOBE' 'WiredTech' 'Supersonic'
#  'SouthAfricanDigitalVillagesPtyLtd' 'VOFFICE' 'Garnaal'
#  'WiFiTechnologies' 'Accelerit' 'IPComms' 'CMValue' 'MikroTikSA'
#  'Deninfiplan' 'LibyaTelecomTechnology' '123NetCptptyLtd' 'TalkTalk'
#  'Netskope' 'MultacomCorporation' 'KiboConnect' 'SecuredServersLLC'
#  'FROGFOOT' 'Bytescon1' 'AirtelMadagascar' 'iONLINEISP' 'ParatusTelecom'
#  'ZAMTEL' 'TelefonicadeEspana' 'AmazonOffice' 'MITSOL' 'HugeNetworks'
#  'A360Cloud' 'Linode' 'INFOGRO' 'Ziggo' 'TelecomItaliaBusiness'
#  'IBITSInternet' 'TruscGroup'
#  'CompagnieFrancaisedAssurancepourleCommerceE' 'EquationBusiness'
#  'TrackerConnect' 'PsychzNetworks' 'Performive' 'Infosatip' 'QuadraNet'
#  'ATTServices' 'MillenicomTurkey' 'Zenex5iveLimited' 'CenturyLink'
#  'ConnectedSpace' 'Touchnettelecommunications' 'DatacampLimited'
#  'ComcastBusiness' 'VodafoneUK' 'Cellcom' 'PCN' 'ECNTelecommunications'
#  'NetiaSA' 'Orange' 'OldMutualInsure' 'Surf4Life' 'EasywebInternetPtyLtd'
#  'Plusnet' 'HitecSure' 'MauritiusTelecom' 'HauptOnline' 'Spectrum' 'IBOSS'
#  'Orcon' 'Enetworks' 'ElisaOyj' 'TVCaboAngola' 'XDSLNetworkingSolutions'
#  'VDBCommunicationsLtd' 'OperaMiniProxy' 'IMAGINE' 'SWAZINET' 'CrispFibre'
#  'VastNetworksPTYLTD' 'DigitalOcean' 'LinuxBasedSystemsDesign'
#  'CipherWave' 'VocusCommunications' 'Fnbconnect'
#  'UABBaltnetoskomunikacijos' 'AirtelKenya' 'ZenInternetLtd' 'TNM'
#  'AltechRadio' 'PacificUniversity' 'HostUniversalPty' 'DeutscheTelekomAG'
#  'TelstraInternet' 'SAA' 'ShawCommunications' 'VodafoneGermanyCable'
#  'VSIC' 'DKWireless' 'CHINAUNICOMIndustrialInternetBackbone'
#  'OlenaTrading' 'SmartSwitch' 'TMobileUSA' 'VocusNewZealand' 'SWDconnect'
#  'TheStandardBankofSouthAfricaLimited' 'NETPAGE' 'VOConnect'
#  'ATTInternetServices' 'Capitecbanklimited' '2degreesMobile' 'Landynamix'
#  'Platformity' 'VodafoneGreece' 'PuntonetSA' 'IomartCloudServicesLimited'
#  'HydraCommunicationsLtd' 'iUncapped' 'AdeptInternetPtyLTD'
#  'LeaseWebNetherlandsBV' 'Capricom' 'CoxCommunications'
#  'VerizonInternetServices' 'TelefonicaO2UK' 'DialogAxiata' 'Izwi'
#  'Webstorm' 'MTNZambia' 'MTCNamibia' 'VodafoneAustralia'
#  'UKDedicatedServersLtd' 'WiredTechPTYLTD' 'vsysorg' 'Ziniaisp'
#  'BioniqLtd' 'GammaTelecom' 'MTNSAMOBILE' 'Proximus' 'LeasewebUSA'
#  'AirtelNetworksLimited' 'IpxoLimited' 'UK2NET' 'DeutschesForschungsnetz'
#  'SoftLayerTechnologies' 'MEO' 'SuddenlinkCommunications'
#  'DigitalIslandLtd' 'BitCoHome' 'IPVanish' 'WTTXCommunications'
#  'ITTXTelecoms' 'TelecomNamibia' 'SonicTelecoms' 'AVASTSoftwaresro'
#  'KurlecWirelessPtyLtd' 'ASKInternetTechnologies' 'JanetUniversityNetwork'
#  'CogentCommunications' 'CityLodgeHotels' 'NetOneCellular'
#  'VodafonePortugal' 'AbsaBank' 'KcomGroupLimited' 'IwayAG' 'ChoopaLLC'
#  'TelecomMalagasy' 'Exponentiale' 'QCSGroup' 'EE' 'Ntelecom' 'ATTWireless'
#  'Belong' 'FirstAmericanRealEstateSolutions' 'LibertyHoldings'
#  'AllianceBroadbandServicesPvt' 'HuaweiCloud' 'TPGInternet' 'MPInet'
#  'WestHost' 'ISPAfrika' 'ATTUverse' 'Zayo' 'Aljeelnet' 'UOFS' 'draadloze'
#  'CybersmartLightspeed' 'Omantel' 'Sudatel' 'Bethnet' 'ServersAustralia'
#  'GigeNET' 'CWayComputers' 'GeneralMotors' 'NetworkPlatforms' 'SAICOM'
#  '24Shells' 'VodafoneGermanyDSL' 'Three' 'ColumbusCommunicationsCuracaoNV'
#  'PermaNet' 'GCoreLabsSA' 'ClouviderLimited' 'VodafoneTurkey'
#  'OracleCorporation' 'edgeconnectlegacy' 'Fibergrid' 'Wirelexx'
#  'AmanahTech' 'RWTHAachenUniversity' 'EBONET' 'RelianceGlobalcomLimited'
#  'AviaSolutionsGroupPlc' 'IqviaSolutionsHqLtd' 'AtlanticBroadband'
#  'ReflexSolutions' 'Advaniasland' 'LeasewebDeutschlandGmbH' 'CompletelSAS'
#  'Siminn' 'NosComunicacoesSA' 'Telekenex' 'Skytictelecom'
#  'SafaricomBusiness' 'EGIHosting' 'KurlecFibrePtyLtd' 'rootSA'
#  'LadysmithWirelessSolutions' 'SONANGOL' 'SAINETInternet' 'Aerocom'
#  'BosveldCommunications' 'Vodafone' 'EmeryTelcom' 'VodacomCongo'
#  'AirtelBroadband' 'Swisscom' 'VTSConnectPTYLTD' 'KABTechnologies'
#  'ChinaMobile' 'AcceleratedConnections' 'IntraLda' 'Lightwire'
#  'KoreaTelecom' 'VodacomTanzania' 'SkylogicMediterraneosrl'
#  'IQVIAOperationsFranceSAS' 'PCNetwork'
#  'BotswanaTelecommunicationsCorporation' 'KenyaEducationNetwork'
#  'ORANGEBUSINESSSERVICESUSInc' 'VodacomMozambique' 'ConnectDirect'
#  'Connesispa' 'FoundationforScienceandTechnologyPortugal']
# os ['Windows_Some(7)' 'Windows_Some(10)' 'Windows_Some(XP)' 'Unknown'
#  'Mac_OS_X_Some(10)' 'Android_Some(8)' 'iOS_Some(12)' 'Linux_None'
#  'Windows_Some(8)' 'Android_Some(4)' 'iOS_Some(9)' 'Windows_Some(Vista)'
#  'iOS_Some(11)' 'Android_Some(7)' 'Android_Some(6)' 'iOS_Some(10)'
#  'Ubuntu_None' 'Android_Some(5)' 'iOS_Some(13)' 'Mac_OS_X_Some(11)'
#  'Other_None' 'Chrome_OS_Some(13505)' 'iOS_Some(14)'
#  'Chrome_OS_Some(10032)' 'Chrome_OS_Some(13597)' 'Tizen_Some(3)'
#  'Chrome_OS_Some(13421)' 'Fedora_None' 'Chrome_OS_Some(11895)'
#  'Chrome_OS_Some(10452)']
# region ['ZA_null' 'ZA_GP' 'outside_ZA' 'ZA_KZN' 'ZA_WC' 'ZA_EC' 'Unknown' 'ZA_FS'
#  'ZA_NW' 'ZA_MP' 'ZA_LP' 'ZA_NC']
# to_bank ['FNBRMB' 'ABSABank' 'Undefined' 'NedbankLimited' 'Unknown' 'CapitecBank'
#  'StandardBank' 'DiscoveryBank' 'InvestecBank' 'HBZBank' 'AfricanBank'
#  'BidvestBank' 'MercantileBank' 'AccessBankSouthAfricaLtd'
#  'StandardCharteredBank' 'GROBANKLTD' 'UBankLimited' 'TymeBank' 'PostBank'
#  'HSBCBank' 'PeoplesBankLtdIncNBS' 'BankofAthens' 'SASFINBank' 'Ithala'
#  'CitiBank' 'TrustcoBankNamibia' 'NedbankLtd' 'BankWindhoek'
#  'AlbarakaBank' 'HabibOverseasBank']

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Target Variable Analysis

# %%
#Check fraud distribution:
# Count of fraudulent vs non-fraudulent transactions
sns.countplot(x='fraud', data=df)
plt.title('Fraudulent vs Non-Fraudulent Transactions')

plt.show()

# Percentage
df['fraud'].value_counts(normalize=True) * 100
# Out:
# fraud
# 0.0    93.597903
# 1.0     6.402097
# Name: proportion, dtype: float64

# %% [markdown]
# ## Numerical Features Analysis

# %%
#Look at distribution and outliers:
num_cols = ['amount', 'customer_age', 'minute_of_day', 'to_acc_volume']

for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True, bins=50)
    plt.title(f'{col} Distribution')

    plt.show()

# %% [markdown]
# ## Categorical Features Analysis

# %%
#Check frequency of categories:
cat_cols = ['browser','channel','onceoff_vs_beneficiary','os','paymentType','region','to_bank']

for col in cat_cols:
    plt.figure(figsize=(8,4))
    df[col].value_counts().plot(kind='bar')
    plt.title(f'{col} Value Counts')
    
    plt.show()

# %% [markdown]
# ## Correlation Analysis

# %%
#Check relationships with fraud:
plt.figure(figsize=(6,5))
sns.heatmap(df[num_cols + ['fraud']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation with Fraud')
plt.show()

# %% [markdown]
# ## Time-based Analysis

# %%
#Check fraud over time:
df['date'] = pd.to_datetime(df['date'])
df.groupby(df['date'].dt.date)['fraud'].mean().plot(figsize=(12,4))
plt.title('Daily Fraud Rate')\

plt.show()

# %% [markdown]
# # Time-based Features

# %%
#Extract from txn_timestamp and loginTime:
df['txn_timestamp'] = pd.to_datetime(df['txn_timestamp'])
df['loginTime'] = pd.to_datetime(df['loginTime'])

# New features
df['hour_of_day'] = df['txn_timestamp'].dt.hour
df['day_of_week'] = df['txn_timestamp'].dt.dayofweek  # Monday=0, Sunday=6
df['session_duration'] = (df['txn_timestamp'] - df['loginTime']).dt.total_seconds()

# %%
df.head()
# Out:
#      amount          browser    channel  customer_age       date  fraud  \
# 0  120000.0  Chrome_Some(66)  channel_B          51.0 2018-06-01    0.0
# 1    1250.0  Chrome_Some(89)  channel_B          26.0 2021-04-07    0.0
# 2     200.0  Chrome_Some(75)  channel_B          82.0 2019-07-31    0.0
# 3      30.0  Chrome_Some(77)  channel_B          37.0 2021-04-13    0.0
# 4     150.0  Chrome_Some(77)  channel_B          32.0 2021-09-25    0.0
#
#                 ip             isp  latitude                 loginTime  ...  \
# 0  102.253.144.146  TelkomInternet  -29.0000 2018-06-01 19:27:21+00:00  ...
# 1    197.89.21.227         OPTINET  -26.3811 2021-04-07 16:10:10+00:00  ...
# 2    169.0.104.125   AFRIHOSTOTHER  -26.3811 2019-07-31 14:31:35+00:00  ...
# 3     34.252.239.0       Amazoncom   53.3382 2021-04-13 21:12:38+00:00  ...
# 4     3.250.216.92       Amazoncom   53.3382 2021-09-25 21:05:45+00:00  ...
#
#    paymentType      region rtc_indicator  to_acc_volume to_bank  \
# 0            F     ZA_null             0           18.0  FNBRMB
# 1            F       ZA_GP             0           21.0  FNBRMB
# 2            F       ZA_GP             0            6.0  FNBRMB
# 3            F  outside_ZA             0       421418.0  FNBRMB
# 4            F  outside_ZA             0       160201.0  FNBRMB
#
#               txn_timestamp transactor_id hour_of_day  day_of_week  \
# 0 2018-06-01 19:46:21+00:00     9150237.0          19            4
# 1 2021-04-07 16:13:39+00:00    13643308.0          16            2
# 2 2019-07-31 14:41:47+00:00       74589.0          14            2
# 3 2021-04-13 21:13:18+00:00     8776804.0          21            1
# 4 2021-09-25 21:06:13+00:00     7653360.0          21            5
#
#    session_duration
# 0            1140.0
# 1             209.0
# 2             612.0
# 3              40.0
# 4              28.0
#
# [5 rows x 26 columns]

# %% [markdown]
# # Customer-based Features

# %%
#Track history with the account:
df['account_age_days'] = (pd.to_datetime(df['lut_last_paid_date']) - pd.to_datetime(df['lut_first_paid_date'])).dt.days
df['avg_payment_amount'] = df['to_acc_volume'] / (df['account_age_days'] + 1)  # +1 to avoid division by zero

# %%
df.head()
# Out:
#      amount          browser    channel  customer_age       date  fraud  \
# 0  120000.0  Chrome_Some(66)  channel_B          51.0 2018-06-01    0.0
# 1    1250.0  Chrome_Some(89)  channel_B          26.0 2021-04-07    0.0
# 2     200.0  Chrome_Some(75)  channel_B          82.0 2019-07-31    0.0
# 3      30.0  Chrome_Some(77)  channel_B          37.0 2021-04-13    0.0
# 4     150.0  Chrome_Some(77)  channel_B          32.0 2021-09-25    0.0
#
#                 ip             isp  latitude                 loginTime  ...  \
# 0  102.253.144.146  TelkomInternet  -29.0000 2018-06-01 19:27:21+00:00  ...
# 1    197.89.21.227         OPTINET  -26.3811 2021-04-07 16:10:10+00:00  ...
# 2    169.0.104.125   AFRIHOSTOTHER  -26.3811 2019-07-31 14:31:35+00:00  ...
# 3     34.252.239.0       Amazoncom   53.3382 2021-04-13 21:12:38+00:00  ...
# 4     3.250.216.92       Amazoncom   53.3382 2021-09-25 21:05:45+00:00  ...
#
#    rtc_indicator to_acc_volume to_bank             txn_timestamp  \
# 0              0          18.0  FNBRMB 2018-06-01 19:46:21+00:00
# 1              0          21.0  FNBRMB 2021-04-07 16:13:39+00:00
# 2              0           6.0  FNBRMB 2019-07-31 14:41:47+00:00
# 3              0      421418.0  FNBRMB 2021-04-13 21:13:18+00:00
# 4              0      160201.0  FNBRMB 2021-09-25 21:06:13+00:00
#
#   transactor_id hour_of_day day_of_week session_duration  account_age_days  \
# 0     9150237.0          19           4           1140.0               0.0
# 1    13643308.0          16           2            209.0             130.0
# 2       74589.0          14           2            612.0             162.0
# 3     8776804.0          21           1             40.0              40.0
# 4     7653360.0          21           5             28.0              14.0
#
#    avg_payment_amount
# 0           18.000000
# 1            0.160305
# 2            0.036810
# 3        10278.487805
# 4        10680.066667
#
# [5 rows x 28 columns]

# %% [markdown]
# # Geolocation Features

# %%
#Using latitude and longitude (convert to float first):
df['latitude'] = pd.to_numeric(df['latitude'], errors='coerce')
df['longitude'] = pd.to_numeric(df['longitude'], errors='coerce')

# Example: distance from major city (e.g., Johannesburg)
import numpy as np

def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # km
    phi1, phi2 = np.radians(lat1), np.radians(lat2)
    dphi = np.radians(lat2 - lat1)
    dlambda = np.radians(lon2 - lon1)
    a = np.sin(dphi/2)**2 + np.cos(phi1)*np.cos(phi2)*np.sin(dlambda/2)**2
    return 2*R*np.arcsin(np.sqrt(a))

# Coordinates of Johannesburg
job_lat, job_lon = -26.2041, 28.0473
df['dist_from_johannesburg'] = haversine(df['latitude'], df['longitude'], job_lat, job_lon)

# %% [markdown]
# # Transaction Behavior Features

# %%
#Create risk indicators:
# High transaction amounts
df['high_amount_flag'] = df['amount'] > df['amount'].quantile(0.95)

# Once-off vs recurring pattern
df['beneficiary_flag'] = df['onceoff_vs_beneficiary'] == 'beneficiary'

# %%
df.head()  # Shows the first 5 rows including new features
df.columns  # Shows all column names
# Out:
# Index(['amount', 'browser', 'channel', 'customer_age', 'date', 'fraud', 'ip',
#        'isp', 'latitude', 'loginTime', 'longitude', 'lut_first_paid_date',
#        'lut_last_paid_date', 'minute_of_day', 'onceoff_vs_beneficiary', 'os',
#        'paymentType', 'region', 'rtc_indicator', 'to_acc_volume', 'to_bank',
#        'txn_timestamp', 'transactor_id', 'hour_of_day', 'day_of_week',
#        'session_duration', 'account_age_days', 'avg_payment_amount',
#        'dist_from_johannesburg', 'high_amount_flag', 'beneficiary_flag'],
#       dtype='object')

# %% [markdown]
# # Exploratory data analysis (EDA) of your new features

# %%
# 1. Distributions of new features
new_features = ['hour_of_day', 'day_of_week', 'session_duration', 
                'account_age_days', 'avg_payment_amount', 
                'dist_from_johannesburg', 'high_amount_flag', 'beneficiary_flag']

for col in new_features:
    plt.figure(figsize=(6,3))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.show()

# 2. Correlation with fraud (numerical features only)
numeric_cols = ['hour_of_day', 'day_of_week', 'session_duration', 
                'account_age_days', 'avg_payment_amount', 
                'dist_from_johannesburg', 'amount']

plt.figure(figsize=(8,5))
corr = df[numeric_cols + ['fraud']].corr()['fraud'].sort_values(ascending=False)
sns.barplot(x=corr.values, y=corr.index)
plt.title("Correlation of numerical features with fraud")
plt.show()

# 3. Fraud rate by categorical flags
for col in ['high_amount_flag', 'beneficiary_flag']:
    rates = df.groupby(col)['fraud'].mean()
    counts = df[col].value_counts()
    print(f"\nFraud rate by {col}:\n", rates)
    print(f"Counts:\n{counts}\n")

    # Barplot
    plt.figure(figsize=(5,3))
    sns.barplot(x=rates.index, y=rates.values)
    plt.title(f"Fraud Rate by {col}")
    plt.ylabel("Fraud Rate")
    plt.show()
# Out:
# Fraud rate by high_amount_flag:
#  high_amount_flag
# False    0.059729
# True     0.147104
# Name: fraud, dtype: float64
# Counts:
# high_amount_flag
# False    50796
# True      2624
# Name: count, dtype: int64
# Fraud rate by beneficiary_flag:
#  beneficiary_flag
# False    0.064021
# Name: fraud, dtype: float64
# Counts:
# beneficiary_flag
# False    53420
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.histplot(data=df, x='hour_of_day', hue='fraud', multiple='stack', bins=24)
plt.title("Transactions by Hour of Day (Fraud vs Non-Fraud)")
plt.show()

# %%
df['account_age_group'] = pd.cut(df['account_age_days'],
                                 bins=[0,30,90,200],
                                 labels=['0-30','31-90','91-200'])

plt.figure(figsize=(7,5))
sns.countplot(x='account_age_group', hue='fraud', data=df)
plt.title('Fraud vs Non-Fraud by Account Age')
plt.xlabel('Account Age Group (days)')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(data=df, x="avg_payment_amount", hue="fraud", bins=50, kde=True, stat="density", common_norm=False)
plt.title("Avg Payment Amount Distribution by Fraud")
plt.xlabel("Average Payment Amount")
plt.ylabel("Density")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="beneficiary_flag", data=df, hue="fraud")
plt.title("Distribution of Beneficiary Flag by Fraud")
plt.xlabel("Beneficiary Flag (0 = Regular, 1 = Once-off)")
plt.ylabel("Count")
plt.show()

# %%
df.head()
# Out:
#      amount          browser    channel  customer_age       date  fraud  \
# 0  120000.0  Chrome_Some(66)  channel_B          51.0 2018-06-01    0.0
# 1    1250.0  Chrome_Some(89)  channel_B          26.0 2021-04-07    0.0
# 2     200.0  Chrome_Some(75)  channel_B          82.0 2019-07-31    0.0
# 3      30.0  Chrome_Some(77)  channel_B          37.0 2021-04-13    0.0
# 4     150.0  Chrome_Some(77)  channel_B          32.0 2021-09-25    0.0
#
#                 ip             isp  latitude                 loginTime  ...  \
# 0  102.253.144.146  TelkomInternet  -29.0000 2018-06-01 19:27:21+00:00  ...
# 1    197.89.21.227         OPTINET  -26.3811 2021-04-07 16:10:10+00:00  ...
# 2    169.0.104.125   AFRIHOSTOTHER  -26.3811 2019-07-31 14:31:35+00:00  ...
# 3     34.252.239.0       Amazoncom   53.3382 2021-04-13 21:12:38+00:00  ...
# 4     3.250.216.92       Amazoncom   53.3382 2021-09-25 21:05:45+00:00  ...
#
#    transactor_id hour_of_day day_of_week  session_duration account_age_days  \
# 0      9150237.0          19           4            1140.0              0.0
# 1     13643308.0          16           2             209.0            130.0
# 2        74589.0          14           2             612.0            162.0
# 3      8776804.0          21           1              40.0             40.0
# 4      7653360.0          21           5              28.0             14.0
#
#   avg_payment_amount dist_from_johannesburg high_amount_flag  \
# 0          18.000000             505.605965             True
# 1           0.160305              28.712179            False
# 2           0.036810              28.712179            False
# 3       10278.487805            9444.172114            False
# 4       10680.066667            9444.172114            False
#
#    beneficiary_flag  account_age_group
# 0             False                NaN
# 1             False             91-200
# 2             False             91-200
# 3             False              31-90
# 4             False               0-30
#
# [5 rows x 32 columns]

# %%
for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.savefig(f"boxplot_{col}.png", dpi=300, bbox_inches='tight')  # Save figure
    plt.show()

# %% [markdown]
# # Data Modeling

# %% [markdown]
# ## Select features and target

# %%
# Features
X = df[['amount', 'customer_age', 'minute_of_day', 'to_acc_volume', 
        'session_duration', 'hour_of_day', 'day_of_week']]
# Target
y = df['fraud']

# %% [markdown]
# ## Train-test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# %% [markdown]
# # Scale numerical features

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

num_cols = ['amount','customer_age','minute_of_day','to_acc_volume','session_duration']
cat_cols = ['hour_of_day','day_of_week']

preprocessor = ColumnTransformer(
    [
        ("standardScaler", StandardScaler(), num_cols),
        ("oneHotEncoder", OneHotEncoder(handle_unknown='ignore'), cat_cols)
    ]
)

X_train_final = preprocessor.fit_transform(X_train)
X_test_final = preprocessor.transform(X_test)

# %%
print(X_train_final)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 261758 stored elements and shape (37394, 36)>
#   Coords	Values
#   (0, 0)	-0.10647989399726081
#   (0, 1)	0.18315776659653152
#   (0, 2)	1.1035183860109292
#   (0, 3)	1.6327265849671886
#   (0, 4)	-0.41887431087141297
#   (0, 14)	1.0
#   (0, 29)	1.0
#   (1, 0)	-0.13854714667822396
#   (1, 1)	-0.602505580737093
#   (1, 2)	0.13386562129361373
#   (1, 3)	-0.1011340335798288
#   (1, 4)	-0.5841212399455159
#   (1, 24)	1.0
#   (1, 29)	1.0
#   (2, 0)	-0.12199630658482362
#   (2, 1)	0.29539538764419215
#   (2, 2)	-0.6553306735631592
#   (2, 3)	-0.38942940740628007
#   (2, 4)	-0.5213692415629452
#   (2, 11)	1.0
#   (2, 30)	1.0
#   (3, 0)	-0.06510279376375998
#   (3, 1)	-0.11614255619723024
#   (3, 2)	-1.5624251953954866
#   (3, 3)	0.8028187879655967
#   :	:
#   (37390, 3)	-0.3888360830578632
#   (37390, 4)	1.5891896373708512
#   (37390, 23)	1.0
#   (37390, 35)	1.0
#   (37391, 0)	-0.1332888068568832
#   (37391, 1)	-0.45285541934021223
#   (37391, 2)	-1.0788018561692325
#   (37391, 3)	-0.38941550136686404
#   (37391, 4)	-0.19924231653241534
#   (37391, 13)	1.0
#   (37391, 34)	1.0
#   (37392, 0)	-0.12630642119247995
#   (37392, 1)	0.8191709525332752
#   (37392, 2)	0.6632045995512054
#   (37392, 3)	-0.3894247720598081
#   (37392, 4)	-0.09883911912030215
#   (37392, 12)	1.0
#   (37392, 33)	1.0
#   (37393, 0)	-0.13278555787529328
#   (37393, 1)	-0.45285541934021223
#   (37393, 2)	0.1314595350288065
#   (37393, 3)	-0.3894433134456961
#   (37393, 4)	-0.03190365417889335
#   (37393, 23)	1.0
#   (37393, 31)	1.0

# %% [markdown]
# ## Save small sample test

# %% [markdown]
# # Check final dataset

# %%
print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
# Out:
# Train shape: (37394, 7)
# Test shape: (16026, 7)

# %% [markdown]
# # Building Baseline Models

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### Import libraries

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score

# %%
from sklearn.impute import SimpleImputer

# Create imputer
imputer = SimpleImputer(strategy='median')

# Fit on training data and transform both train and test
X_train[['session_duration']] = imputer.fit_transform(X_train[['session_duration']])
X_test[['session_duration']] = imputer.transform(X_test[['session_duration']])

# %% [markdown]
# ### Create and train the model

# %%
# Create the model
model = LogisticRegression(max_iter=1000, random_state=42)

# Train on training data
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %% [markdown]
# ### Make predictions

# %%
# Predict class labels
y_pred = model.predict(X_test)

# Predict probabilities (for ROC-AUC)
y_prob = model.predict_proba(X_test)[:, 1]

# %% [markdown]
# ### Evaluate the model

# %%
# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)

# Classification report
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# ROC-AUC score
auc = roc_auc_score(y_test, y_prob)
print("\nROC-AUC Score:", auc)
# Out:
# Confusion Matrix:
#  [[14993     7]
#  [ 1008    18]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97     15000
#          1.0       0.72      0.02      0.03      1026
#
#     accuracy                           0.94     16026
#    macro avg       0.83      0.51      0.50     16026
# weighted avg       0.92      0.94      0.91     16026
#
#
# ROC-AUC Score: 0.7419658869395712

# %%
print("Total dataset:", len(X))
print("Training set:", len(X_train))
print("Test set:", len(X_test))

print("\nFraud counts in training set:")
print(y_train.value_counts())

print("\nFraud counts in test set:")
print(y_test.value_counts())
# Out:
# Total dataset: 53420
# Training set: 37394
# Test set: 16026
#
# Fraud counts in training set:
# fraud
# 0.0    35000
# 1.0     2394
# Name: count, dtype: int64
#
# Fraud counts in test set:
# fraud
# 0.0    15000
# 1.0     1026
# Name: count, dtype: int64

# %% [markdown]
# ## Decision Tree Model

# %% [markdown]
# ### Train Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# Train the model
dt_model = DecisionTreeClassifier(random_state=42, max_depth=5)  # you can tune depth
dt_model.fit(X_train, y_train)

# Predictions
y_pred_dt = dt_model.predict(X_test)
y_prob_dt = dt_model.predict_proba(X_test)[:,1]

# %% [markdown]
# ### Evaluate

# %%
# Confusion Matrix
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_dt))

# Classification Report
print("\nClassification Report:\n", classification_report(y_test, y_pred_dt))

# ROC-AUC Score
print("\nROC-AUC Score:", roc_auc_score(y_test, y_prob_dt))
# Out:
# Confusion Matrix:
#  [[14917    83]
#  [  470   556]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98     15000
#          1.0       0.87      0.54      0.67      1026
#
#     accuracy                           0.97     16026
#    macro avg       0.92      0.77      0.82     16026
# weighted avg       0.96      0.97      0.96     16026
#
#
# ROC-AUC Score: 0.922388986354776

# %% [markdown]
# ## Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# Random Forest model
rf_model = RandomForestClassifier(
    n_estimators=100,
    max_depth=None,
    random_state=42,
    class_weight='balanced'
)

rf_model.fit(X_train_final, y_train)

y_pred_rf = rf_model.predict(X_test_final)
y_proba_rf = rf_model.predict_proba(X_test_final)[:, 1]

cm_rf = confusion_matrix(y_test, y_pred_rf)
cr_rf = classification_report(y_test, y_pred_rf, digits=2)
acc_rf = accuracy_score(y_test, y_pred_rf)
roc_auc_rf = roc_auc_score(y_test, y_proba_rf)

print("Confusion Matrix:\n", cm_rf)
print("\nClassification Report:\n", cr_rf)
print("\nAccuracy:", acc_rf)
print("\nRandom Forest ROC-AUC:", roc_auc_rf)

fpr, tpr, thresholds = roc_curve(y_test, y_proba_rf)
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f'Random Forest (AUC = {roc_auc_rf:.3f})')
plt.plot([0,1],[0,1],'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Random Forest')
plt.legend()
plt.show()
# Out:
# Confusion Matrix:
#  [[14933    67]
#  [  355   671]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99     15000
#          1.0       0.91      0.65      0.76      1026
#
#     accuracy                           0.97     16026
#    macro avg       0.94      0.82      0.87     16026
# weighted avg       0.97      0.97      0.97     16026
#
#
# Accuracy: 0.9736677898415076
#
# Random Forest ROC-AUC: 0.9721697530864198
